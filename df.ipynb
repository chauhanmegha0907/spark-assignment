# %%
# File: spark_dataframe.py
from pyspark.sql import SparkSession
import glob

def create_spark_dataframe():
    spark = SparkSession.builder \
        .appName("COVID-19 Analysis") \
        .getOrCreate()

    # Read data from CSV into Spark DataFrame
    df_list = []
    for file_name in glob.glob('*_covid_data.csv'):
        df = spark.read.csv(file_name, header=True)
        df_list.append(df)

    # Merge DataFrames into a single DataFrame
    merged_df = df_list[0]
    for df in df_list[1:]:
        merged_df = merged_df.union(df)

    return merged_df

df = create_spark_dataframe()
df.show()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/03/28 15:31:08 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# +-------------+------------+--------------------+---------+----------+-------+-----------+---------+--------------+--------+--------+------------------+-------------------+----------+------------------+----------+-------------+----------------+-----------------+----------------+-------------------+----------------------+---------------------+
# |      updated|     country|         countryInfo|    cases|todayCases| deaths|todayDeaths|recovered|todayRecovered|  active|critical|casesPerOneMillion|deathsPerOneMillion|     tests|testsPerOneMillion|population|    continent|oneCasePerPeople|oneDeathPerPeople|oneTestPerPeople|activePerOneMillion|recoveredPerOneMillion|criticalPerOneMillion|
# +-------------+------------+--------------------+---------+----------+-------+-----------+---------+--------------+--------+--------+------------------+-------------------+----------+------------------+----------+-------------+----------------+-----------------+----------------+-------------------+----------------------+---------------------+
# |1711610850970|      Turkey|{'_id': 792, 'iso...| 17232066|         0| 102174|          0|        0|             0|17129892|       0|            201399|               1194| 162743369|           1902052|  85561976|         Asia|               5|              837|               1|          200204.49|                     0|                    0|
# |1711610850982|        Iran|{'_id': 364, 'iso...|  7627186|         0| 146811|          0|        0|             0| 7480375|       0|             88665|               1707|  57320267|            666338|  86022837|         Asia|              11|              586|               2|           86958.01|                     0|                    0|
# |1711610850983|   Indonesia|{'_id': 360, 'iso...|  6829162|         0| 162063|          0|  6647104|             0|   19995|       0|             24465|                581| 114158919|            408975| 279134505|         Asia|              41|             1722|               2|              71.63|              23813.27|                    0|
# |1711610850980|      Mexico|{'_id': 484, 'iso...|  7702809|         0| 334958|          0|  6899865|             0|  467986|       0|             58549|               2546|  20013810|            152124| 131562772|North America|              17|              393|               7|            3557.13|              52445.42|                    0|
# |1711610850985|      Poland|{'_id': 616, 'iso...|  6661789|         0| 120597|          0|        0|             0| 6541192|       0|            176519|               3195|  39317656|           1041809|  37739785|       Europe|               6|              313|               1|          173323.51|                     0|                    0|
# |1711610851006|        Peru|{'_id': 604, 'iso...|  4572667|         0| 222161|          0|  4350506|             0|       0|       4|            135751|               6595|  39010194|           1158115|  33684208|South America|               7|              152|               1|                  0|             129155.66|                 0.12|
# |1711610850962|      Brazil|{'_id': 76, 'iso2...| 38694221|         0| 710966|          0| 36249161|             0| 1734094|       0|            179678|               3301|  63776166|            296146| 215353593|South America|               6|              303|               3|            8052.31|             168323.92|                    0|
# |1711610850987|    Colombia|{'_id': 170, 'iso...|  6400173|         0| 143200|          0|  6212152|             0|   44821|     342|            124244|               2780|  36951507|            717327|  51512762|South America|               8|              360|               1|              870.1|             120594.43|                 6.64|
# |1711610850968|          UK|{'_id': 826, 'iso...| 24910387|         0| 232112|          0| 24675212|             0|    3063|       0|            363666|               3389| 522526476|           7628357|  68497907|       Europe|               3|              295|               0|              44.72|             360233.08|                    0|
# |1711610850967|       Italy|{'_id': 380, 'iso...| 26722143|         0| 196446|          0| 26356336|             0|  169361|      27|            443427|               3260| 280910073|           4661420|  60262770|       Europe|               2|              307|               0|            2810.38|             437356.86|                 0.45|
# |1711610850994|     Ukraine|{'_id': 804, 'iso...|  5557995|         0| 112418|          0|  5445577|             0|       0|       0|            128681|               2603|  32603805|            754855|  43192122|       Europe|               8|              384|               1|                  0|             126078.01|                    0|
# |1711610850956|       India|{'_id': 356, 'iso...| 45033893|         0| 533540|          0|        0|             0|44500353|       0|             32015|                379| 935879495|            665334|1406631776|         Asia|              31|             2636|               2|           31636.11|                     0|                    0|
# |1711610850979| Netherlands|{'_id': 528, 'iso...|  8635591|         0|  22992|          0|  8612069|             0|     530|       0|            501735|               1336|  25984435|           1509718|  17211447|       Europe|               2|              749|               1|              30.79|             500368.68|                    0|
# |1711610850978|   Argentina|{'_id': 32, 'iso2...| 10094643|         0| 130733|          0|  9963910|             0|       0|       0|            219400|               2841|  35716069|            776264|  46010234|South America|               5|              352|               1|                  0|             216558.56|                    0|
# |1711610850969|      Russia|{'_id': 643, 'iso...| 24082671|         0| 402612|          0| 23500207|             0|  179852|       0|            165169|               2761| 273400000|           1875095| 145805947|       Europe|               6|              362|               1|             1233.5|             161174.54|                    0|
# |1711610851010|South Africa|{'_id': 710, 'iso...|  4076463|         0| 102595|          0|  3912506|             0|   61362|     192|             67095|               1689|  26795090|            441027|  60756135|       Africa|              15|              592|               2|            1009.97|              64396.89|                 3.16|
# |1711610850945|         USA|{'_id': 840, 'iso...|111752653|         0|1218763|          0|109682509|             0|  851381|    1111|            333784|               3640|1186851502|           3544901| 334805269|North America|               3|              275|               0|            2542.91|              327600.9|                 3.32|
# +-------------+------------+--------------------+---------+----------+-------+-----------+---------+--------------+--------+--------+------------------+-------------------+----------+------------------+----------+-------------+----------------+-----------------+----------------+-------------------+----------------------+---------------------+

# %%
from pyspark.sql import SparkSession

# Initialize SparkSession
spark = SparkSession.builder \
    .appName("COVID-19 Data Analysis") \
    .getOrCreate()

# Read the CSV files into a DataFrame
covid_df = spark.read.csv('*.csv', header=True)  # Assuming all CSV files are in the same directory

# Print schema of the DataFrame
print("Schema of the DataFrame:")
covid_df.printSchema()

# Display the first few rows of the DataFrame
print("First few rows of the DataFrame:")
covid_df.show()

# Calculate aggregate statistics
total_cases = covid_df.selectExpr("sum(cases) as total_cases").collect()[0]["total_cases"]
total_deaths = covid_df.selectExpr("sum(deaths) as total_deaths").collect()[0]["total_deaths"]

print("Total COVID-19 cases:", total_cases)
print("Total COVID-19 deaths:", total_deaths)

# Perform further analysis as needed
# Out:
# Schema of the DataFrame:
# root
#  |-- updated: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- countryInfo: string (nullable = true)
#  |-- cases: string (nullable = true)
#  |-- todayCases: string (nullable = true)
#  |-- deaths: string (nullable = true)
#  |-- todayDeaths: string (nullable = true)
#  |-- recovered: string (nullable = true)
#  |-- todayRecovered: string (nullable = true)
#  |-- active: string (nullable = true)
#  |-- critical: string (nullable = true)
#  |-- casesPerOneMillion: string (nullable = true)
#  |-- deathsPerOneMillion: string (nullable = true)
#  |-- tests: string (nullable = true)
#  |-- testsPerOneMillion: string (nullable = true)
#  |-- population: string (nullable = true)
#  |-- continent: string (nullable = true)
#  |-- oneCasePerPeople: string (nullable = true)
#  |-- oneDeathPerPeople: string (nullable = true)
#  |-- oneTestPerPeople: string (nullable = true)
#  |-- activePerOneMillion: string (nullable = true)
#  |-- recoveredPerOneMillion: string (nullable = true)
#  |-- criticalPerOneMillion: string (nullable = true)
#
# First few rows of the DataFrame:
# +-------------+------------+--------------------+---------+----------+-------+-----------+---------+--------------+--------+--------+------------------+-------------------+----------+------------------+----------+-------------+----------------+-----------------+----------------+-------------------+----------------------+---------------------+
# |      updated|     country|         countryInfo|    cases|todayCases| deaths|todayDeaths|recovered|todayRecovered|  active|critical|casesPerOneMillion|deathsPerOneMillion|     tests|testsPerOneMillion|population|    continent|oneCasePerPeople|oneDeathPerPeople|oneTestPerPeople|activePerOneMillion|recoveredPerOneMillion|criticalPerOneMillion|
# +-------------+------------+--------------------+---------+----------+-------+-----------+---------+--------------+--------+--------+------------------+-------------------+----------+------------------+----------+-------------+----------------+-----------------+----------------+-------------------+----------------------+---------------------+
# |1711610850945|         USA|{'_id': 840, 'iso...|111752653|         0|1218763|          0|109682509|             0|  851381|    1111|            333784|               3640|1186851502|           3544901| 334805269|North America|               3|              275|               0|            2542.91|              327600.9|                 3.32|
# |1711610850967|       Italy|{'_id': 380, 'iso...| 26722143|         0| 196446|          0| 26356336|             0|  169361|      27|            443427|               3260| 280910073|           4661420|  60262770|       Europe|               2|              307|               0|            2810.38|             437356.86|                 0.45|
# |1711610850962|      Brazil|{'_id': 76, 'iso2...| 38694221|         0| 710966|          0| 36249161|             0| 1734094|       0|            179678|               3301|  63776166|            296146| 215353593|South America|               6|              303|               3|            8052.31|             168323.92|                    0|
# |1711610850987|    Colombia|{'_id': 170, 'iso...|  6400173|         0| 143200|          0|  6212152|             0|   44821|     342|            124244|               2780|  36951507|            717327|  51512762|South America|               8|              360|               1|              870.1|             120594.43|                 6.64|
# |1711610851010|South Africa|{'_id': 710, 'iso...|  4076463|         0| 102595|          0|  3912506|             0|   61362|     192|             67095|               1689|  26795090|            441027|  60756135|       Africa|              15|              592|               2|            1009.97|              64396.89|                 3.16|
# |1711610850980|      Mexico|{'_id': 484, 'iso...|  7702809|         0| 334958|          0|  6899865|             0|  467986|       0|             58549|               2546|  20013810|            152124| 131562772|North America|              17|              393|               7|            3557.13|              52445.42|                    0|
# |1711610850972|       Spain|{'_id': 724, 'iso...| 13914811|         0| 121760|          0| 13762417|             0|   30634|     231|            297840|               2606| 471036328|          10082298|  46719142|       Europe|               3|              384|               0|             655.71|             294577.69|                 4.94|
# |1711610850969|      Russia|{'_id': 643, 'iso...| 24082671|         0| 402612|          0| 23500207|             0|  179852|       0|            165169|               2761| 273400000|           1875095| 145805947|       Europe|               6|              362|               1|             1233.5|             161174.54|                    0|
# |1711610850960|     Germany|{'_id': 276, 'iso...| 38826304|         0| 182891|          0| 38240600|             0|  402813|       0|            462859|               2180| 122332384|           1458359|  83883596|       Europe|               2|              459|               1|            4802.05|             455876.98|                    0|
# |1711610850979| Netherlands|{'_id': 528, 'iso...|  8635591|         0|  22992|          0|  8612069|             0|     530|       0|            501735|               1336|  25984435|           1509718|  17211447|       Europe|               2|              749|               1|              30.79|             500368.68|                    0|
# |1711610850978|   Argentina|{'_id': 32, 'iso2...| 10094643|         0| 130733|          0|  9963910|             0|       0|       0|            219400|               2841|  35716069|            776264|  46010234|South America|               5|              352|               1|                  0|             216558.56|                    0|
# |1711610850983|   Indonesia|{'_id': 360, 'iso...|  6829162|         0| 162063|          0|  6647104|             0|   19995|       0|             24465|                581| 114158919|            408975| 279134505|         Asia|              41|             1722|               2|              71.63|              23813.27|                    0|
# |1711610851006|        Peru|{'_id': 604, 'iso...|  4572667|         0| 222161|          0|  4350506|             0|       0|       4|            135751|               6595|  39010194|           1158115|  33684208|South America|               7|              152|               1|                  0|             129155.66|                 0.12|
# |1711610850968|          UK|{'_id': 826, 'iso...| 24910387|         0| 232112|          0| 24675212|             0|    3063|       0|            363666|               3389| 522526476|           7628357|  68497907|       Europe|               3|              295|               0|              44.72|             360233.08|                    0|
# |1711610850958|      France|{'_id': 250, 'iso...| 40138560|         0| 167642|          0| 39970918|             0|       0|       0|            612013|               2556| 271490188|           4139547|  65584518|       Europe|               2|              391|               0|                  0|             609456.61|                    0|
# |1711610850970|      Turkey|{'_id': 792, 'iso...| 17232066|         0| 102174|          0|        0|             0|17129892|       0|            201399|               1194| 162743369|           1902052|  85561976|         Asia|               5|              837|               1|          200204.49|                     0|                    0|
# |1711610850956|       India|{'_id': 356, 'iso...| 45033893|         0| 533540|          0|        0|             0|44500353|       0|             32015|                379| 935879495|            665334|1406631776|         Asia|              31|             2636|               2|           31636.11|                     0|                    0|
# |1711610850985|      Poland|{'_id': 616, 'iso...|  6661789|         0| 120597|          0|        0|             0| 6541192|       0|            176519|               3195|  39317656|           1041809|  37739785|       Europe|               6|              313|               1|          173323.51|                     0|                    0|
# |1711610850994|     Ukraine|{'_id': 804, 'iso...|  5557995|         0| 112418|          0|  5445577|             0|       0|       0|            128681|               2603|  32603805|            754855|  43192122|       Europe|               8|              384|               1|                  0|             126078.01|                    0|
# |1711610850982|        Iran|{'_id': 364, 'iso...|  7627186|         0| 146811|          0|        0|             0| 7480375|       0|             88665|               1707|  57320267|            666338|  86022837|         Asia|              11|              586|               2|           86958.01|                     0|                    0|
# +-------------+------------+--------------------+---------+----------+-------+-----------+---------+--------------+--------+--------+------------------+-------------------+----------+------------------+----------+-------------+----------------+-----------------+----------------+-------------------+----------------------+---------------------+
# 24/03/28 15:31:14 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
# Total COVID-19 cases: 449466187.0
# Total COVID-19 deaths: 5367434.0

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder .appName("COVID-19 Data Processing").getOrCreate()

df.write.csv('covid_data.csv', header=True, mode='overwrite')
# Out:
# 24/03/28 15:46:56 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.
